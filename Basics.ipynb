# %% [markdown]
# VISUALIZING EARNING BASED ON COLLEGE MAJORS
#
# On this project we will be working with different type of visualizations. We will perform different visualization with out data sets to better understand the data we are working with.
#
# Some of the Questions we can answer include:
# Do students in more popular majors make more money?
#
# How many majors are predominantly male or female?
#
# Which category of majors have the most students?

# %%
#Importing needed libraries and the files needed
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

recent_grads = pd.read_csv('recent-grads.csv')

# %%
#Exploring the first row to get familiar with the table
recent_grads.iloc[:1]
# Out:
#    Rank  Major_code                  Major   Total     Men  Women  \
# 0     1        2419  PETROLEUM ENGINEERING  2339.0  2057.0  282.0
#
#   Major_category  ShareWomen  Sample_size  Employed      ...        Part_time  \
# 0    Engineering    0.120564           36      1976      ...              270
#
#    Full_time_year_round  Unemployed  Unemployment_rate  Median  P25th   P75th  \
# 0                  1207          37           0.018381  110000  95000  125000
#
#    College_jobs  Non_college_jobs  Low_wage_jobs
# 0          1534               364            193
#
# [1 rows x 21 columns]

# %%
#Exploring the fist 5 rows to get familiar and understand the dataset
recent_grads.head()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
#Continuation of data exploration by checking the end to make sure there is continuation
recent_grads.tail()
# Out:
#      Rank  Major_code                   Major   Total     Men   Women  \
# 168   169        3609                 ZOOLOGY  8409.0  3050.0  5359.0
# 169   170        5201  EDUCATIONAL PSYCHOLOGY  2854.0   522.0  2332.0
# 170   171        5202     CLINICAL PSYCHOLOGY  2838.0   568.0  2270.0
# 171   172        5203   COUNSELING PSYCHOLOGY  4626.0   931.0  3695.0
# 172   173        3501         LIBRARY SCIENCE  1098.0   134.0   964.0
#
#                Major_category  ShareWomen  Sample_size  Employed  \
# 168    Biology & Life Science    0.637293           47      6259
# 169  Psychology & Social Work    0.817099            7      2125
# 170  Psychology & Social Work    0.799859           13      2101
# 171  Psychology & Social Work    0.798746           21      3777
# 172                 Education    0.877960            2       742
#
#          ...        Part_time  Full_time_year_round  Unemployed  \
# 168      ...             2190                  3602         304
# ...

# %%
#Now we will be exploring the summary statistics and explore all the numerical columns
recent_grads.describe()
# Out:
#              Rank   Major_code          Total            Men          Women  \
# count  173.000000   173.000000     172.000000     172.000000     172.000000
# mean    87.000000  3879.815029   39370.081395   16723.406977   22646.674419
# std     50.084928  1687.753140   63483.491009   28122.433474   41057.330740
# min      1.000000  1100.000000     124.000000     119.000000       0.000000
# 25%     44.000000  2403.000000    4549.750000    2177.500000    1778.250000
# 50%     87.000000  3608.000000   15104.000000    5434.000000    8386.500000
# 75%    130.000000  5503.000000   38909.750000   14631.000000   22553.750000
# max    173.000000  6403.000000  393735.000000  173809.000000  307087.000000
#
#        ShareWomen  Sample_size       Employed      Full_time      Part_time  \
# count  172.000000   173.000000     173.000000     173.000000     173.000000
# mean     0.522223   356.080925   31192.763006   26029.306358    8832.398844
# ...

# %%
#Now exploring the number of data to make sure we do not have any missing values
raw_data_count = recent_grads.count()

# %%
recent_grads = recent_grads.dropna()

# %%
clean_data_count = recent_grads.count()
clean_data_count
# Out:
# Rank                    172
# Major_code              172
# Major                   172
# Total                   172
# Men                     172
# Women                   172
# Major_category          172
# ShareWomen              172
# Sample_size             172
# Employed                172
# Full_time               172
# Part_time               172
# Full_time_year_round    172
# Unemployed              172
# Unemployment_rate       172
# Median                  172
# P25th                   172
# P75th                   172
# College_jobs            172
# Non_college_jobs        172
# Low_wage_jobs           172
# dtype: int64

# %% [markdown]
# As we can see in comparing the Cleaned_data_count and raw_data_count only one row containing missing data was dropped. Now we will be working with clean data sets

# %% [markdown]
# DATA EXPLORATION USING VISUALS
#
# PANDAS SCATTER PLOT

# %%
ax1 = recent_grads.plot('Sample_size', 'Median', kind= 'scatter')

# %%
ax2 = recent_grads.plot('Sample_size', 'Unemployment_rate', kind= 'scatter')

# %%
ax3 = recent_grads.plot('Full_time', 'Median', kind= 'scatter')

# %%
ax4 = recent_grads.plot('ShareWomen', 'Unemployment_rate', kind= 'scatter')

# %%
ax5 = recent_grads.plot('Men', 'Median', kind= 'scatter')

# %%
ax6 = recent_grads.plot('Women', 'Median', kind= 'scatter')

# %%
ax7 = recent_grads.plot('Total', 'Median', kind= 'scatter')

# %% [markdown]
# As we can see from the different data exploration especially with the last plot the most popular majors do not necesarily make the most. The trend almost show the exact opposite actually.

# %% [markdown]
# PANDAS HISTOGRAM

# %%
recent_grads['Sample_size'].hist(bins=20, range=(0, 5000))

# %%
recent_grads['Median'].hist(bins=20, range=(0, 80000))

# %%
recent_grads['Employed'].hist(bins=20, range=(0, 35000))

# %%
recent_grads['Full_time'].hist(bins=20, range=(0, 5000))

# %%
recent_grads['ShareWomen'].hist(bins=20, range=(0, 1.2))

# %%
recent_grads['Unemployment_rate'].hist(bins=20, range=(0, 0.20))

# %%
recent_grads['Men'].hist(bins=20, range=(0, 200000))

# %%
recent_grads['Women'].hist(bins=20, range=(0, 350000))

# %% [markdown]
# PANDAS SCATTER PLOT MATRIX
#
# These make it easier to spot any relationships that are present in our datasets

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f567b29cb38>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize=(8,8))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f567b0cb978>,
# ...
#       dtype=object)

# %% [markdown]
# PANDAS BAR PLOTS

# %%
#Showing percentage of women from the first 10 rows
recent_grads[:10].plot.bar(x='Major', y='ShareWomen', legend=False)

# %%
#Shows the percent of w
recent_grads[163:].plot.bar(x='Major', y='ShareWomen', legend=False)

# %% [markdown]
# As We can see from some of the analysis from these last few plots the amount of women in some of the popular majors is very low compare to the least popular majors. This is reflected also when you look at salary because the high pay majors have less wo
